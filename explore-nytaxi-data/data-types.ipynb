# %% [markdown]
# ## DATA TYPES
# This notebook looks at the data types of the NY taxi CSV files for the date range that we are using in the DataTalks class.

# %%
import pandas as pd
import numpy as np  
import os 
from io import BytesIO
import requests
import utils

# %%
services = ['fhv','green','yellow']
init_url = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/'

# %% [markdown]
# ## It appears that the data format of multiple columns changed in Aug 2019

# %%
dtypes_green_2019 = utils.get_service_year_dtypes(services[1], 2019)

# %%
print(dtypes_green_2019.shape)
dtypes_green_2019
# Out:
# (20, 24)
#                        01_2019  n_01_2019  02_2019  n_02_2019  03_2019  \
# Column Name
# VendorID                 {int}          2    {int}          2    {int}
# lpep_pickup_datetime     {str}     541269    {str}     494374    {str}
# lpep_dropoff_datetime    {str}     540701    {str}     493358    {str}
# store_and_fwd_flag       {str}          2    {str}          2    {str}
# RatecodeID               {int}          6    {int}          7    {int}
# PULocationID             {int}        256    {int}        258    {int}
# DOLocationID             {int}        261    {int}        260    {int}
# passenger_count          {int}         10    {int}         10    {int}
# trip_distance          {float}       3255  {float}       3308  {float}
# fare_amount            {float}       5438  {float}       5506  {float}
# extra                  {float}          8  {float}         15  {float}
# mta_tax                {float}          4  {float}          4  {float}
# ...

# %%
dtypes_green_2020 = utils.get_service_year_dtypes(services[1], 2020)

# %%
dtypes_green_2020
# Out:
#                             01_2020  n_01_2020       02_2020  n_02_2020  \
# Column Name
# VendorID                    {float}          2       {float}          2
# lpep_pickup_datetime          {str}     331157         {str}     316285
# lpep_dropoff_datetime         {str}     331043         {str}     316272
# store_and_fwd_flag     {float, str}          2  {float, str}          2
# RatecodeID                  {float}          7       {float}          7
# PULocationID                  {int}        251         {int}        254
# DOLocationID                  {int}        257         {int}        258
# passenger_count             {float}         10       {float}          9
# trip_distance               {float}       3555       {float}       3056
# fare_amount                 {float}       6037       {float}       4366
# extra                       {float}         13       {float}         37
# mta_tax                     {float}          4       {float}          4
# ...

# %%
dtypes_yellow_2019 = utils.get_service_year_dtypes(services[2], 2019)

# %%
dtypes_yellow_2019
# Out:
#                        01_2019  n_01_2019  02_2019  n_02_2019  03_2019  \
# Column Name
# VendorID                 {int}          3    {int}          3    {int}
# tpep_pickup_datetime     {str}    2245960    {str}    2039881    {str}
# tpep_dropoff_datetime    {str}    2250229    {str}    2043000    {str}
# passenger_count          {int}         10    {int}         10    {int}
# trip_distance          {float}       4390  {float}       4339  {float}
# RatecodeID               {int}          7    {int}          7    {int}
# store_and_fwd_flag       {str}          2    {str}          2    {str}
# PULocationID             {int}        263    {int}        261    {int}
# DOLocationID             {int}        261    {int}        262    {int}
# payment_type             {int}          4    {int}          4    {int}
# fare_amount            {float}       6278  {float}       6263  {float}
# extra                  {float}         37  {float}         43  {float}
# ...

# %%
dtypes_yellow_2020 = utils.get_service_year_dtypes(services[2], 2020)

# %%
dtypes_yellow_2020
# Out:
#                             01_2020  n_01_2020       02_2020  n_02_2020  \
# Column Name
# VendorID                    {float}          2       {float}          2
# tpep_pickup_datetime          {str}    2134342         {str}    2027136
# tpep_dropoff_datetime         {str}    2137286         {str}    2031299
# passenger_count             {float}         10       {float}         10
# trip_distance               {float}       5606       {float}       4391
# RatecodeID                  {float}          7       {float}          7
# store_and_fwd_flag     {float, str}          2  {float, str}          2
# PULocationID                  {int}        261         {int}        259
# DOLocationID                  {int}        262         {int}        261
# payment_type                {float}          5       {float}          4
# fare_amount                 {float}       5283       {float}       5137
# extra                       {float}         47       {float}        122
# ...

# %%
dtypes_fhv_2019 = utils.get_service_year_dtypes(services[0], 2019)

# %%
dtypes_fhv_2019
# Out:
#                              01_2019  n_01_2019       02_2019  n_02_2019  \
# Column Name
# dispatching_base_num    {float, str}        609         {str}        466
# pickup_datetime                {str}    2617832         {str}    1083886
# dropOff_datetime               {str}    2619363         {str}    1103657
# PUlocationID                 {float}        264       {float}        260
# DOlocationID                 {float}        265       {float}        260
# SR_Flag                      {float}         43       {float}          2
# Affiliated_base_number  {float, str}       1517  {float, str}        656
#
#                              03_2019  n_03_2019       04_2019  n_04_2019  \
# Column Name
# dispatching_base_num           {str}        527         {str}        516
# pickup_datetime                {str}     979542         {str}    1148389
# dropOff_datetime               {str}     994036         {str}    1185351
# ...
