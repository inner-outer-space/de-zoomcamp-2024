# %%
import pandas as pd
import pyarrow.parquet as pq

# %%
pd.__version__

# %%
green_zip = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz"

# %%
#!wget -O data/green_cab_zone.zip "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/green_tripdata_2019-09.csv.gz"
parquet_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2019-01.parquet" 
url = "data/ny_taxi_postgres_data/green_tripdata_2019-09.csv"

# %%
#parquet_url = "https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2021-01.parquet"
trips = pd.read_parquet(parquet_url)
print(trips.shape)
trips.head()
# Out:
# (672105, 20)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0           264           264              5.0           0.00
# 1         1.0            97            49              2.0           0.86
# 2         1.0            49           189              2.0           0.66
# 3         1.0           189            17              2.0           2.68
# 4         1.0            82           258              1.0           4.53
#
# ...

# %%
trips.info()

# %%
trips = pq.read_table('trips.parquet')
trips = trips.to_pandas()

# %%
#df = pd.read_csv('yellow_tripdata_2021-01.csv', nrows=100)
#df = pd.read_csv(url, nrows=100)
df = pd.read_csv(url)
df.head()
# Out:
# /tmp/ipykernel_35987/2506136865.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# ...

# %%
print(df.shape)
df.info()
# Out:
# (449063, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449063 entries, 0 to 449062
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               389920 non-null  float64
#  1   lpep_pickup_datetime   449063 non-null  object
#  2   lpep_dropoff_datetime  449063 non-null  object
#  3   store_and_fwd_flag     389920 non-null  object
#  4   RatecodeID             389920 non-null  float64
#  5   PULocationID           449063 non-null  int64
#  6   DOLocationID           449063 non-null  int64
#  7   passenger_count        389920 non-null  float64
#  8   trip_distance          449063 non-null  float64
#  9   fare_amount            449063 non-null  float64
#  10  extra                  449063 non-null  float64
#  11  mta_tax                449063 non-null  float64
#  12  tip_amount             449063 non-null  float64
# ...

# %%
#df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               100 non-null    int64
#  1   lpep_pickup_datetime   100 non-null    datetime64[ns]
#  2   lpep_dropoff_datetime  100 non-null    datetime64[ns]
#  3   store_and_fwd_flag     100 non-null    object
#  4   RatecodeID             100 non-null    int64
#  5   PULocationID           100 non-null    int64
#  6   DOLocationID           100 non-null    int64
#  7   passenger_count        100 non-null    int64
#  8   trip_distance          100 non-null    float64
#  9   fare_amount            100 non-null    float64
#  10  extra                  100 non-null    float64
#  11  mta_tax                100 non-null    float64
#  12  tip_amount             100 non-null    float64
#  13  tolls_amount           100 non-null    float64
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
#print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
print(pd.io.sql.get_schema(df, name='green_taxi_data_fromCSV', con=engine))
# Out:
# CREATE TABLE "green_taxi_data_fromCSV" (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
#df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)
df_iter = pd.read_csv(url, iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
#df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1             2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2             2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3             2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4             2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-09-08 21:34:31   2019-09-08 21:42:44                  N
# 99996         2  2019-09-08 21:06:54   2019-09-08 21:12:38                  N
# 99997         2  2019-09-08 21:22:10   2019-09-08 21:29:33                  N
# 99998         2  2019-09-08 21:33:42   2019-09-08 21:33:48                  N
# 99999         2  2019-09-08 21:29:16   2019-09-08 21:36:45                  N
#
# ...

# %%
df.head(n=0).to_sql(name='green_taxi_data_fromCSV', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='green_taxi_data_fromCSV', con=engine, if_exists='append')
# Out:
# CPU times: user 3.94 s, sys: 119 ms, total: 4.06 s
# Wall time: 5.97 s
# 1000

# %%
from time import time

# %%
while True: 
    t_start = time()

    df = next(df_iter)

    #df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    #df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df.to_sql(name='green_taxi_data_fromCSV', con=engine, if_exists='append')

    t_end = time()

    print('inserted another chunk, took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk, took 5.913 second
# inserted another chunk, took 5.849 second
# /tmp/ipykernel_35987/1938062206.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 6.084 second
# inserted another chunk, took 2.535 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[19], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next(df_iter)
#       6     #df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       7     #df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#       8     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#
# File ~/anaconda3/envs/de_zoom/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1668, in TextFileReader.__next__(self)
# ...

# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
