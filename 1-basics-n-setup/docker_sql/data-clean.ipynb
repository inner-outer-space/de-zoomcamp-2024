# %%
import pandas as pd
import numpy as np  
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
import os 
from datetime import datetime
import mappings as mp

# %%
parquet_name = 'data/yellow_taxi_jan_2021.parquet'
csv_name = 'data/ny_taxi_location_lookup.csv'
data_url="https://d37ci6vzurychx.cloutaxi_df_cleanront.net/trip-data/yellow_tripdata_2021-01.parquet"
lookup_url="https://d37ci6vzurychx.cloutaxi_df_cleanront.net/misc/taxi+_zone_lookup.csv"

# %%
# ONE TIME DOWNLOAD  
# os.system(f'wget -O {parquet_name} {data_url}')
# os.system(f'wget -O {csv_name} {lookup_url}')

# %%
# READ IN DATA 
taxi_df_orig = pd.read_parquet(parquet_name)

# %%
# CHECK MEMORY USAGE 
memory_usage = taxi_df_orig.memory_usage(deep=True).sum() / (1024 ** 2)  # Convert to megabytes
print(f"Memory usage of DataFrame: {memory_usage:.2f} MB")
# Out:
# Memory usage of DataFrame: 260.69 MB

# %% [markdown]
# # MAPPINGS

# %%
# IMPORT MAPPING DICTIONARY
mapping = mp.mapping_dict
print(f'data type:{type(mapping)}', f'an example value: {mapping["payment_type"][3]}')
#dir(mappings)
# Out:
# data type:<class 'dict'> an example value: No charge

# %% [markdown]
# # BASIC INFO AND STATS

# %%
taxi_df = taxi_df_orig.copy()
taxi_df.columns = taxi_df.columns.str.lower()
columns = taxi_df.columns
columns
# Out:
# Index(['vendorid', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'ratecodeid', 'store_and_fwd_flag',
#        'pulocationid', 'dolocationid', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
taxi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1369769 entries, 0 to 1369768
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   vendorid               1369769 non-null  int64
#  1   tpep_pickup_datetime   1369769 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  1369769 non-null  datetime64[us]
#  3   passenger_count        1271417 non-null  float64
#  4   trip_distance          1369769 non-null  float64
#  5   ratecodeid             1271417 non-null  float64
#  6   store_and_fwd_flag     1271417 non-null  object
#  7   pulocationid           1369769 non-null  int64
#  8   dolocationid           1369769 non-null  int64
#  9   payment_type           1369769 non-null  int64
#  10  fare_amount            1369769 non-null  float64
#  11  extra                  1369769 non-null  float64
#  12  mta_tax                1369769 non-null  float64
#  13  tip_amount             1369769 non-null  float64
#  14  tolls_amount           1369769 non-null  float64
#  15  improvement_surcharge  1369769 non-null  float64
#  16  total_amount           1369769 non-null  float64
#  17  congestion_surcharge   1271417 non-null  float64
#  18  airport_fee            5 non-null        float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# memory usage: 198.6+ MB

# %% [markdown]
# #### REPLACE STORE AND FORWARD FLAG WITH A NUMERIC VALUE FOR ANALYSIS PURPOSES

# %%
print(taxi_df['store_and_fwd_flag'].unique())  
# Replace "Y" with 1 and "N" with 2 
taxi_df['store_and_fwd_flag'] = taxi_df['store_and_fwd_flag'].replace({"Y": 1, "N": 2}).astype(float) 
print(taxi_df['store_and_fwd_flag'].unique())
# Out:
# ['N' 'Y' None]
# [ 2.  1. nan]

# %% [markdown]
# #### LOOK AT NA, NULL, AND ZERO COUNTS

# %%
def nan_null_zero_datatypes(df):
    have_values = [(df[col].notna() & (df[col] != 0)).sum() for col in df.columns]
    nans = [df[col].isna().sum() for col in df.columns]
    blanks = [(df[col] == ' ').sum() for col in df.columns]
    zeros = [(df[col] == 0).sum() for col in df.columns]
    data_types = [df[col].apply(lambda x: type(x)).unique() for col in df.columns]
    len_data_types = [len(df[col].apply(lambda x: type(x)).unique()) for col in df.columns] 
    

    df_clean_check = pd.DataFrame({
        'Column Name': df.columns,
        'have_values': have_values,
        '# NAs': nans,
        '# Blanks': blanks,
        '# Zeros': zeros,
        '# Data Types': len_data_types,
        'Data Types': data_types
    })

    return df_clean_check

# %%
taxi_df_info = nan_null_zero_datatypes(taxi_df)
taxi_df_info
# Out:
#               Column Name  have_values    # NAs  # Blanks  # Zeros  \
# 0                vendorid      1369769        0         0        0
# 1    tpep_pickup_datetime      1369769        0         0        0
# 2   tpep_dropoff_datetime      1369769        0         0        0
# 3         passenger_count      1244691    98352         0    26726
# 4           trip_distance      1349817        0         0    19952
# 5              ratecodeid      1271417    98352         0        0
# 6      store_and_fwd_flag      1271417    98352         0        0
# 7            pulocationid      1369769        0         0        0
# 8            dolocationid      1369769        0         0        0
# 9            payment_type      1271417        0         0    98352
# 10            fare_amount      1369127        0         0      642
# 11                  extra       683716        0         0   686053
# 12                mta_tax      1363821        0         0     5948
# 13             tip_amount       948287        0         0   421482
# 14           tolls_amount        51867        0         0  1317902
# 15  improvement_surcharge      1369111        0         0      658
# 16           total_amount      1369317        0         0      452
# 17   congestion_surcharge      1149696    98352         0   121721
# 18            airport_fee            0  1369764         0        5
#
#     # Data Types                                         Data Types
# 0              1                                    [<class 'int'>]
# 1              1  [<class 'pandas._libs.tslibs.timestamps.Timest...
# 2              1  [<class 'pandas._libs.tslibs.timestamps.Timest...
# 3              1                                  [<class 'float'>]
# 4              1                                  [<class 'float'>]
# 5              1                                  [<class 'float'>]
# 6              1                                  [<class 'float'>]
# 7              1                                    [<class 'int'>]
# 8              1                                    [<class 'int'>]
# 9              1                                    [<class 'int'>]
# 10             1                                  [<class 'float'>]
# 11             1                                  [<class 'float'>]
# 12             1                                  [<class 'float'>]
# 13             1                                  [<class 'float'>]
# 14             1                                  [<class 'float'>]
# 15             1                                  [<class 'float'>]
# 16             1                                  [<class 'float'>]
# 17             1                                  [<class 'float'>]
# 18             1                                  [<class 'float'>]

# %% [markdown]
# ## BASIC STATS

# %%
taxi_df.describe().round(2)
# Out:
#          vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  1369769.00                     1369769                     1369769
# mean         1.72  2021-01-17 01:48:30.539849  2021-01-17 02:02:25.240572
# min          1.00         2008-12-31 23:05:14         2008-12-31 23:07:22
# 25%          1.00         2021-01-09 13:42:49         2021-01-09 13:55:05
# 50%          2.00         2021-01-16 20:10:32         2021-01-16 20:24:06
# 75%          2.00         2021-01-24 15:32:45         2021-01-24 15:44:59
# max          6.00         2021-02-22 16:52:16         2021-02-22 16:56:15
# std          0.59                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count       1271417.00     1369769.00  1271417.00          1271417.00
# mean              1.41           4.63        1.04                1.99
# min               0.00           0.00        1.00                1.00
# 25%               1.00           1.00        1.00                2.00
# 50%               1.00           1.70        1.00                2.00
# 75%               1.00           3.02        1.00                2.00
# max               8.00      263163.28       99.00                2.00
# std               1.06         393.90        0.60                0.12
#
#        pulocationid  dolocationid  payment_type  fare_amount       extra  \
# count    1369769.00    1369769.00    1369769.00   1369769.00  1369769.00
# mean         165.25        161.50          1.19        12.10        0.97
# min            1.00          1.00          0.00      -490.00       -5.50
# 25%          124.00        107.00          1.00         6.00        0.00
# 50%          162.00        162.00          1.00         8.50        0.00
# 75%          236.00        236.00          1.00        13.50        2.50
# max          265.00        265.00          4.00      6960.50        8.25
# std           67.84         72.11          0.58        12.91        1.23
#
#           mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# count  1369769.00  1369769.00    1369769.00             1369769.00
# mean         0.49        1.92          0.25                   0.30
# min         -0.50     -100.00        -31.12                  -0.30
# 25%          0.50        0.00          0.00                   0.30
# 50%          0.50        1.86          0.00                   0.30
# 75%          0.50        2.75          0.00                   0.30
# max          0.50     1140.44        811.75                   0.30
# std          0.08        2.60          1.67                   0.04
#
#        total_amount  congestion_surcharge  airport_fee
# count    1369769.00            1271417.00          5.0
# mean          17.47                  2.24          0.0
# min         -492.80                 -2.50          0.0
# 25%           10.80                  2.50          0.0
# 50%           13.80                  2.50          0.0
# 75%           19.12                  2.50          0.0
# max         7661.28                  3.00          0.0
# std           14.69                  0.80          0.0

# %% [markdown]
# #### UNDERSTANDING THE DISCRETE VALUE COLUMNS

# %%
# PRINT UNIQUE VALUES FOR COLUMNS WITH DISCRETE VALUES
print("Value counts for columns with discrete values:")
for col in taxi_df.columns:
    unique_values = taxi_df[col].unique()
    if len(unique_values) < 20:
        print(f"{col}:")
        for value in unique_values:
            count = (taxi_df[col] == value).sum()
            print(f"    {value}: {count}")
            
        # OR FOLLOWING THE FIRST PRINT
        #value_counts = taxi_df[col].value_counts()
        #for value, count in value_counts.items():
        #    print(f"    {value}: {count}")
# Out:
# Value counts for columns with discrete values:
# vendorid:
#     1: 422337
#     2: 937141
#     6: 10291
# passenger_count:
#     1.0: 966236
#     0.0: 26726
#     2.0: 161671
#     3.0: 43935
#     5.0: 31089
#     4.0: 16391
#     6.0: 25362
#     8.0: 2
#     7.0: 5
#     nan: 0
# ratecodeid:
#     1.0: 1249243
#     2.0: 14858
#     4.0: 1202
#     5.0: 5212
#     3.0: 856
#     99.0: 36
#     6.0: 10
#     nan: 0
# store_and_fwd_flag:
#     2.0: 1252433
#     1.0: 18984
#     nan: 0
# payment_type:
#     2: 322891
#     1: 934475
#     4: 5667
#     3: 8384
#     0: 98352
# mta_tax:
#     0.5: 1357263
#     0.0: 5948
#     -0.5: 6558
# improvement_surcharge:
#     0.3: 1362457
#     0.0: 658
#     -0.3: 6654
# congestion_surcharge:
#     2.5: 1144198
#     0.0: 121721
#     -2.5: 5495
#     0.75: 2
#     3.0: 1
#     nan: 0
# airport_fee:
#     nan: 0
#     0.0: 5

# %% [markdown]
# ## ADD NEW COLUMNS
# Adding now because duration will be used to select some records for removal.
#
# - duration_minute
# - holiday flag
# - math check --> Total Amount - Fare and all Fees/ Charges
#
# EVENTUALLY WANT TO ADD
# - Weather - temp and percipitation (rain/snow) flag
# - Daytime - flag Y if between sunrise and sunset for that day

# %%
# BREAK OUT DROP OFF DATE INTO SEPARATE COLUMNS
taxi_df['drop_off_day'] = taxi_df['tpep_dropoff_datetime'].dt.day
taxi_df['drop_off_hour'] = taxi_df['tpep_dropoff_datetime'].dt.hour
taxi_df['drop_off_dow'] = taxi_df['tpep_dropoff_datetime'].dt.dayofweek

# ADD PICK UP DATE INTO SEPARATE COLUMNS
taxi_df['pick_up_day'] = taxi_df['tpep_pickup_datetime'].dt.day
taxi_df['pick_up_hour'] = taxi_df['tpep_pickup_datetime'].dt.hour
taxi_df['pick_up_dow'] = taxi_df['tpep_pickup_datetime'].dt.dayofweek

# ADD DURATION IN MINUTES COLUMN
taxi_df['duration_minute'] = (
    (taxi_df['tpep_dropoff_datetime'] - taxi_df['tpep_pickup_datetime'])
    .apply(lambda x: round(x.total_seconds() / 60))
    .astype(int)
)

taxi_df.head()
# Out:
#    vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  dolocationid  \
# 0           2.10         1.0                 2.0           142            43
# 1           0.20         1.0                 2.0           238           151
# 2          14.70         1.0                 2.0           132           165
# 3          10.60         1.0                 2.0           138           132
# 4           4.94         1.0                 2.0            68            33
#
#    payment_type  ...  total_amount  congestion_surcharge  airport_fee  \
# 0             2  ...         11.80                   2.5          NaN
# 1             2  ...          4.30                   0.0          NaN
# 2             1  ...         51.95                   0.0          NaN
# 3             1  ...         36.35                   0.0          NaN
# 4             1  ...         24.36                   2.5          NaN
#
#    drop_off_day  drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  \
# 0             1              0             4            1             0
# 1             1              0             4            1             0
# 2             1              1             4            1             0
# 3             1              0             4            1             0
# 4             1              0             4            1             0
#
#    pick_up_dow  duration_minute
# 0            4                6
# 1            4                1
# 2            4               28
# 3            4               15
# 4            4               17
#
# [5 rows x 26 columns]

# %%
# ADD HOLIDAY FLAG COLUMN

# List of US holidays in Jan 2021 
holidays = ['2021-01-01', '2021-01-18'] 

# Add a holiday flag column
taxi_df['is_holiday'] = (
    taxi_df['tpep_dropoff_datetime']
    .apply(lambda x: x.strftime('%Y-%m-%d') in holidays)
)

# Look at records with holidays
holiday = taxi_df[taxi_df['is_holiday'] == True]
print(f"Records with holidays: {holiday.shape[0]}")
holiday.tail()
# Out:
# Records with holidays: 61799
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1327476         2  2021-01-18 23:10:53   2021-01-18 23:17:15              NaN
# 1327477         2  2021-01-18 23:02:59   2021-01-18 23:32:29              NaN
# 1327478         2  2021-01-18 23:17:00   2021-01-18 23:36:00              NaN
# 1327482         2  2021-01-18 23:19:00   2021-01-18 23:33:00              NaN
# 1327483         2  2021-01-18 23:17:00   2021-01-18 23:35:43              NaN
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 1327476           0.55         NaN                 NaN            75
# 1327477           7.33         NaN                 NaN            65
# 1327478          10.94         NaN                 NaN           134
# 1327482           6.54         NaN                 NaN            76
# 1327483           4.88         NaN                 NaN             9
#
#          dolocationid  payment_type  ...  congestion_surcharge  airport_fee  \
# 1327476            75             0  ...                   NaN          NaN
# 1327477            76             0  ...                   NaN          NaN
# 1327478            80             0  ...                   NaN          NaN
# 1327482           215             0  ...                   NaN          NaN
# 1327483           196             0  ...                   NaN          NaN
#
#          drop_off_day  drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  \
# 1327476            18             23             0           18            23
# 1327477            18             23             0           18            23
# 1327478            18             23             0           18            23
# 1327482            18             23             0           18            23
# 1327483            18             23             0           18            23
#
#          pick_up_dow  duration_minute  is_holiday
# 1327476            0                6        True
# 1327477            0               30        True
# 1327478            0               19        True
# 1327482            0               14        True
# 1327483            0               19        True
#
# [5 rows x 27 columns]

# %%
# CHECK IF THE AMOUNTS ADD UP

money_cols = ['payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'congestion_surcharge', 'total_amount', 'math_check']

taxi_df['math_check'] = (
    taxi_df['total_amount'] -
    taxi_df['extra'] -
    taxi_df['mta_tax'] -
    taxi_df['tip_amount'] -
    taxi_df['tolls_amount'] -
    taxi_df['improvement_surcharge'] -
    taxi_df['congestion_surcharge'] -
    taxi_df['fare_amount']
).round(2)


math_check_df = taxi_df[taxi_df['math_check'] != 0]
print(math_check_df.shape[0])
# Out:
# 464658

# %% [markdown]
# # QUESTIONABLE DATA
# ### Look into these further
#
# - **airport_fee** -- only 5 records with 0 and rest nan --> drop this columns
# - **negatives**
# - **NaNs** -- - 98352 records with NA in passenger_count, rate_code_id, store_and_fwd_flag, and congestion_surcharge and 0 in Payment type<br> --> account for **.07%** of the records
# - **trip distance** -- 19952 records with trip_distance = 0
# - **vendor_id** -- 10291 records with vendor_id = 6
# - **passengers** -- 26726 records with 0 passengers
# - **ratecodeid** -- 36 records with ratecodeid = 99
# - **total amount** 452 records with 0 total amount
# - negative amounts - check to see if all negative taxes correspond to negative amounts -- guessing they are refunds

# %% [markdown]
# ### DROP AIRPORT FEE COLUMN

# %%
# DROP THE AIRPORT FEE COLUMN
taxi_df = taxi_df.drop('airport_fee', axis=1)
taxi_df.shape
# Out:
# (1369769, 27)

# %% [markdown]
# ### NEGATIVE AMOUNTS
# First suspected that these were refunds but the records have non negative trip distances.
# The rows with neg fare amount will be dropped. That captures all but few rows with other neg values.

# %%
# LOOK AT COUNTS OF NEGATIVE VALUES
print('COUNTS OF NEGATIVE VALUES PER COLUMN')
for col in taxi_df.columns:
    if taxi_df[col].dtype != 'datetime64[us]':
        negatives = (taxi_df[col] < 0).sum()
        if negatives > 0: 
            print(f"    {col}: {negatives}")
# Out:
# COUNTS OF NEGATIVE VALUES PER COLUMN
#     fare_amount: 6769
#     extra: 2292
#     mta_tax: 6558
#     tip_amount: 59
#     tolls_amount: 139
#     improvement_surcharge: 6654
#     total_amount: 6662
#     congestion_surcharge: 5495
#     duration_minute: 2509
#     math_check: 365789

# %%
# CONFIRM THAT ALMOST ALL OF THE NEGATIVE TAXES, CHARGES ETC OCCUR WITH THE NEGATIVE FARES
neg_fare = taxi_df[taxi_df['fare_amount'] < 0]
for col in neg_fare.columns:
    if neg_fare[col].dtype != 'datetime64[us]':
        negatives = (neg_fare[col] < 0).sum()
        if negatives > 0: 
            print(f"    {col}: {negatives}")
# Out:
#     fare_amount: 6769
#     extra: 2290
#     mta_tax: 6554
#     tip_amount: 57
#     tolls_amount: 139
#     improvement_surcharge: 6654
#     total_amount: 6662
#     congestion_surcharge: 5495
#     math_check: 2

# %%
# STATS FOR NEGATIVE FARES DATAFRAME
neg_fare.describe().round(2)
# Out:
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count   6769.00                        6769                        6769
# mean       2.00  2021-01-16 19:27:53.208155  2021-01-16 19:37:04.878711
# min        2.00         2021-01-01 00:11:01         2021-01-01 00:13:56
# 25%        2.00         2021-01-08 18:42:26         2021-01-08 18:59:18
# 50%        2.00         2021-01-16 15:59:37         2021-01-16 16:00:59
# 75%        2.00         2021-01-24 15:49:18         2021-01-24 16:12:02
# max        6.00         2021-01-31 23:45:23         2021-01-31 23:45:28
# std        0.08                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count          6655.00        6769.00     6655.00              6655.0
# mean              1.36           1.84        1.12                 2.0
# min               1.00           0.00        1.00                 2.0
# 25%               1.00           0.20        1.00                 2.0
# 50%               1.00           0.74        1.00                 2.0
# 75%               1.00           1.81        1.00                 2.0
# max               6.00          34.35        5.00                 2.0
# std               0.92           3.33        0.58                 0.0
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count       6769.00       6769.00       6769.00  ...       6769.00
# mean         161.17        160.31          3.31  ...        -13.41
# min            3.00          1.00          0.00  ...       -492.80
# 25%          107.00        100.00          3.00  ...        -13.80
# 50%          161.00        162.00          4.00  ...         -8.80
# 75%          234.00        234.00          4.00  ...         -6.80
# max          265.00        265.00          4.00  ...         29.00
# std           68.08         72.23          0.85  ...         16.32
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count               6655.00       6769.00        6769.00       6769.00
# mean                  -2.06         16.22          13.73          3.02
# min                   -2.50          1.00           0.00          0.00
# 25%                   -2.50          8.00          11.00          1.00
# 50%                   -2.50         16.00          14.00          3.00
# 75%                   -2.50         24.00          17.00          5.00
# max                    0.00         31.00          23.00          6.00
# std                    0.95          8.85           5.12          1.90
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count      6769.00       6769.00      6769.00          6769.00     6655.00
# mean         16.22         13.69         3.02             9.18       -0.00
# min           1.00          0.00         0.00             0.00       -5.00
# 25%           8.00         11.00         1.00             2.00        0.00
# 50%          16.00         14.00         3.00             4.00        0.00
# 75%          24.00         17.00         5.00            10.00        0.00
# max          31.00         23.00         6.00          1437.00       -0.00
# std           8.85          5.08         1.90            49.62        0.09
#
# [8 rows x 26 columns]

# %%
nan_neg_fare = neg_fare.isna().sum()
print(nan_neg_fare)
# Out:
# vendorid                   0
# tpep_pickup_datetime       0
# tpep_dropoff_datetime      0
# passenger_count          114
# trip_distance              0
# ratecodeid               114
# store_and_fwd_flag       114
# pulocationid               0
# dolocationid               0
# payment_type               0
# fare_amount                0
# extra                      0
# mta_tax                    0
# tip_amount                 0
# tolls_amount               0
# improvement_surcharge      0
# total_amount               0
# congestion_surcharge     114
# drop_off_day               0
# drop_off_hour              0
# drop_off_dow               0
# pick_up_day                0
# pick_up_hour               0
# pick_up_dow                0
# duration_minute            0
# is_holiday                 0
# math_check               114
# dtype: int64

# %% [markdown]
# ### CHECK NaN RECORDS
# All NaNs are in the same rows. These rows will be dropped.

# %%
# CHECK IF ALL NaNs ARE IN THE SAME ROWS
na_check = taxi_df[taxi_df['passenger_count'].isna()]
print(f"Rows with NAs: {na_check.shape[0]} ")
na_check.describe().round(2)
# Out:
# Rows with NAs: 98352
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count   98352.0                       98352                       98352
# mean        2.3  2021-01-16 17:40:36.754270  2021-01-16 18:02:16.080466
# min         1.0         2021-01-01 00:01:04         2021-01-01 00:01:02
# 25%         2.0  2021-01-08 20:56:55.250000  2021-01-08 21:14:09.250000
# 50%         2.0         2021-01-15 22:27:00         2021-01-15 22:45:27
# 75%         2.0  2021-01-24 12:00:23.250000  2021-01-24 12:09:41.250000
# max         6.0         2021-01-31 23:56:00         2021-02-01 00:38:00
# std         1.3                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count              0.0       98352.00         0.0                 0.0
# mean               NaN          29.67         NaN                 NaN
# min                NaN           0.00         NaN                 NaN
# 25%                NaN           2.10         NaN                 NaN
# 50%                NaN           4.74         NaN                 NaN
# 75%                NaN           9.69         NaN                 NaN
# max                NaN      263163.28         NaN                 NaN
# std                NaN        1423.81         NaN                 NaN
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count      98352.00      98352.00       98352.0  ...      98352.00
# mean         151.42        135.55           0.0  ...         31.03
# min            1.00          1.00           0.0  ...        -64.30
# 25%           75.00         71.00           0.0  ...         19.71
# 50%          151.00        137.00           0.0  ...         27.30
# 75%          233.00        210.00           0.0  ...         39.50
# max          265.00        265.00           0.0  ...        159.36
# std           81.80         76.15           0.0  ...         15.37
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count                   0.0      98352.00       98352.00      98352.00
# mean                    NaN         16.19          13.03          2.80
# min                     NaN          1.00           0.00          0.00
# 25%                     NaN          8.00          10.00          1.00
# 50%                     NaN         15.00          13.00          3.00
# 75%                     NaN         24.00          16.00          4.00
# max                     NaN         31.00          23.00          6.00
# std                     NaN          8.59           4.60          1.87
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count     98352.00      98352.00     98352.00         98352.00         0.0
# mean         16.19         12.75         2.80            21.66         NaN
# min           1.00          0.00         0.00            -1.00         NaN
# 25%           8.00          9.00         1.00            10.00         NaN
# 50%          15.00         13.00         3.00            18.00         NaN
# 75%          24.00         16.00         4.00            30.00         NaN
# max          31.00         23.00         6.00          1680.00         NaN
# std           8.59          4.57         1.87            17.27         NaN
#
# [8 rows x 26 columns]

# %%
na_check[na_check['trip_distance'] == 0].shape
# Out:
# (1195, 27)

# %% [markdown]
# ### RECORDS WITH TRIP DISTANCE = 0
# These records will be kept but will be excluded from any distance stats.

# %%
# RECORDS WITH 0 TRIP DISTANCE
zero_distance = taxi_df[taxi_df['trip_distance'] == 0]
print(f"Records with 0 trip distance: {zero_distance.shape[0]} ")
zero_distance.describe().round(2)
# Out:
# Records with 0 trip distance: 19952
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  19952.00                       19952                       19952
# mean       1.31  2021-01-16 04:21:24.583700  2021-01-16 04:35:58.715617
# min        1.00         2008-12-31 23:05:14         2008-12-31 23:07:22
# 25%        1.00         2021-01-08 17:55:49  2021-01-08 18:19:07.250000
# 50%        1.00         2021-01-15 14:07:15         2021-01-15 14:22:00
# 75%        2.00         2021-01-23 15:27:39         2021-01-23 15:38:12
# max        2.00         2021-01-31 23:49:23         2021-02-01 00:22:26
# std        0.46                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count         18757.00        19952.0    18757.00            18757.00
# mean              1.13            0.0        1.78                1.95
# min               0.00            0.0        1.00                1.00
# 25%               1.00            0.0        1.00                2.00
# 50%               1.00            0.0        1.00                2.00
# 75%               1.00            0.0        1.00                2.00
# max               8.00            0.0       99.00                2.00
# std               0.67            0.0        3.56                0.21
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count      19952.00      19952.00      19952.00  ...      19952.00
# mean         148.87        152.73          1.34  ...         22.77
# min            1.00          1.00          0.00  ...       -492.80
# 25%           80.00         78.00          1.00  ...          6.80
# 50%          145.00        151.00          1.00  ...         18.00
# 75%          224.00        231.00          2.00  ...         30.00
# max          265.00        265.00          4.00  ...        900.35
# std           73.96         78.65          0.78  ...         29.34
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count              18757.00      19952.00       19952.00      19952.00
# mean                   0.45         15.82          13.69          2.86
# min                   -2.50          1.00           0.00          0.00
# 25%                    0.00          8.00          11.00          1.00
# 50%                    0.00         15.00          14.00          3.00
# 75%                    0.00         23.00          17.00          4.00
# max                    3.00         31.00          23.00          6.00
# std                    1.06          8.55           5.10          1.89
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count     19952.00      19952.00     19952.00         19952.00    18757.00
# mean         15.82         13.59         2.85            14.52       -0.24
# min           1.00          0.00         0.00            -4.00       -5.00
# 25%           8.00         11.00         1.00             0.00        0.00
# 50%          15.00         14.00         3.00             6.00        0.00
# 75%          23.00         17.00         4.00            23.00        0.00
# max          31.00         23.00         6.00          4419.00        5.00
# std           8.55          5.03         1.89            46.87        0.75
#
# [8 rows x 26 columns]

# %% [markdown]
# ### RECORDS WITH INVALID VENDOR ID (6)
# These all occur with the NaN combo. They will be dropped with the NaN drop.

# %%
# RECORDS WITH VENDOR ID = 6
vendor_6 = taxi_df[taxi_df['vendorid'] == 6]
print(f"Records with vendor id = 6: {vendor_6.shape[0]} ")
vendor_6.describe().round(2)
# Out:
# Records with vendor id = 6: 10291
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count   10291.0                       10291                       10291
# mean        6.0  2021-01-16 01:46:30.566417  2021-01-16 02:08:51.288893
# min         6.0         2021-01-01 00:01:04         2021-01-01 00:01:02
# 25%         6.0         2021-01-08 13:01:58         2021-01-08 14:01:03
# 50%         6.0         2021-01-15 08:01:37         2021-01-15 09:01:01
# 75%         6.0  2021-01-23 13:01:09.500000         2021-01-23 13:01:03
# max         6.0         2021-01-31 23:01:55         2021-02-01 00:02:03
# std         0.0                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count              0.0       10291.00         0.0                 0.0
# mean               NaN           7.17         NaN                 NaN
# min                NaN           0.09         NaN                 NaN
# 25%                NaN           2.85         NaN                 NaN
# 50%                NaN           5.82         NaN                 NaN
# 75%                NaN          10.36         NaN                 NaN
# max                NaN          32.62         NaN                 NaN
# std                NaN           5.38         NaN                 NaN
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count       10291.0      10291.00       10291.0  ...      10291.00
# mean          265.0        125.06           0.0  ...         28.61
# min           265.0          3.00           0.0  ...          0.80
# 25%           265.0         62.00           0.0  ...         17.11
# 50%           265.0        117.00           0.0  ...         26.76
# 75%           265.0        190.00           0.0  ...         35.23
# max           265.0        265.00           0.0  ...         99.37
# std             0.0         74.30           0.0  ...         12.59
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count                   0.0      10291.00       10291.00      10291.00
# mean                    NaN         15.54          12.99          3.14
# min                     NaN          1.00           0.00          0.00
# 25%                     NaN          8.00          10.00          1.00
# 50%                     NaN         15.00          13.00          3.00
# 75%                     NaN         23.00          16.00          5.00
# max                     NaN         31.00          23.00          6.00
# std                     NaN          8.72           4.60          1.94
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count     10291.00      10291.00     10291.00         10291.00         0.0
# mean         15.54         12.74         3.14            22.35         NaN
# min           1.00          0.00         0.00            -1.00         NaN
# 25%           8.00          9.00         1.50             0.00         NaN
# 50%          15.00         13.00         3.00             0.00         NaN
# 75%          23.00         16.00         5.00            59.00         NaN
# max          31.00         23.00         6.00          1680.00         NaN
# std           8.72          4.55         1.94            34.54         NaN
#
# [8 rows x 26 columns]

# %% [markdown]
# ### RECORDS WITH NO PASSENGERS
# This could be a data entry error. These records will be kept but excluded from per passenger stats

# %%
# RECORDS WITH 0 PASSANGERS
zero_passangers = taxi_df[taxi_df['passenger_count'] == 0]
print(f"Records with 0 passengers: {zero_passangers.shape[0]} ")
zero_passangers.describe().round(2)
# Out:
# Records with 0 passengers: 26726
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  26726.00                       26726                       26726
# mean       1.00  2021-01-17 00:48:41.100090  2021-01-17 00:59:19.589014
# min        1.00         2021-01-01 00:01:13         2021-01-01 00:14:01
# 25%        1.00  2021-01-09 14:09:11.250000  2021-01-09 14:18:55.500000
# 50%        1.00  2021-01-16 16:33:28.500000  2021-01-16 16:42:43.500000
# 75%        1.00  2021-01-24 13:50:11.500000  2021-01-24 14:01:36.250000
# max        2.00         2021-01-31 23:48:50         2021-02-01 00:29:22
# std        0.06                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count          26726.0       26726.00    26726.00            26726.00
# mean               0.0           2.54        1.09                1.95
# min                0.0           0.00        1.00                1.00
# 25%                0.0           0.90        1.00                2.00
# 50%                0.0           1.50        1.00                2.00
# 75%                0.0           2.70        1.00                2.00
# max                0.0         326.10       99.00                2.00
# std                0.0           3.84        2.19                0.21
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count      26726.00      26726.00      26726.00  ...      26726.00
# mean         166.09        163.96          1.32  ...         16.41
# min            1.00          1.00          1.00  ...          0.00
# 25%          132.00        107.00          1.00  ...         10.35
# 50%          162.00        162.00          1.00  ...         13.30
# 75%          236.00        236.00          2.00  ...         17.75
# max          265.00        265.00          4.00  ...       1155.65
# std           65.03         70.88          0.55  ...         14.93
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count              26726.00      26726.00       26726.00      26726.00
# mean                   2.26         16.44          13.91          2.93
# min                    0.00          1.00           0.00          0.00
# 25%                    2.50          9.00          11.00          1.00
# 50%                    2.50         16.00          14.00          3.00
# 75%                    2.50         24.00          17.00          4.00
# max                    2.50         31.00          23.00          6.00
# std                    0.74          8.57           4.39          1.88
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count     26726.00      26726.00     26726.00         26726.00    26726.00
# mean         16.44         13.77         2.93            10.64       -2.26
# min           1.00          0.00         0.00             0.00       -2.50
# 25%           9.00         11.00         1.00             5.00       -2.50
# 50%          16.00         14.00         3.00             8.00       -2.50
# 75%          24.00         17.00         4.00            14.00       -2.50
# max          31.00         23.00         6.00           520.00        0.00
# std           8.57          4.35         1.88             8.94        0.74
#
# [8 rows x 26 columns]

# %%
# ONlY 5 RECORDS WITH 0 PASSENGERS AND ZERO FARE
zero_passangers[zero_passangers['total_amount'] == 0].shape
# Out:
# (5, 27)

# %% [markdown]
# ### RECORDS WITH INVALID RATECODEID
# There are only 36 records. These will be deleted since there are not that many and it will make analysis easier later.
# Could try and figure out how the rate code is determined and see if the cost per time or distance matches the other rate codes... but that is too much work for 36 records.

# %%
# RECORDS WITH RATECODEID = 99
ratecodeid_99 = taxi_df[taxi_df['ratecodeid'] == 99]
print(f"Records with ratecodeid = 99: {ratecodeid_99.shape[0]} ")
ratecodeid_99.describe().round(2)
# Out:
# Records with ratecodeid = 99: 36
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count     36.00                          36                          36
# mean       1.50  2021-01-18 14:27:31.805555         2021-01-18 14:56:38
# min        1.00         2021-01-01 07:55:52         2021-01-01 08:04:02
# 25%        1.00  2021-01-13 05:58:12.500000         2021-01-13 05:58:20
# 50%        1.50         2021-01-20 20:32:09         2021-01-21 03:12:55
# 75%        2.00  2021-01-22 14:03:25.500000  2021-01-22 14:03:25.500000
# max        2.00         2021-01-31 09:56:31         2021-01-31 10:09:01
# std        0.51                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count            36.00          36.00        36.0               36.00
# mean              0.72           1.19        99.0                1.86
# min               0.00           0.00        99.0                1.00
# 25%               0.00           0.00        99.0                2.00
# 50%               1.00           0.00        99.0                2.00
# 75%               1.00           0.80        99.0                2.00
# max               2.00          18.17        99.0                2.00
# std               0.61           3.20         0.0                0.35
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count         36.00         36.00         36.00  ...         36.00
# mean         194.92        205.00          1.86  ...         48.56
# min           15.00         13.00          1.00  ...          0.00
# 25%          135.75        142.50          1.75  ...          6.80
# 50%          232.50        261.00          2.00  ...         17.30
# 75%          264.00        264.00          2.00  ...         35.48
# max          264.00        264.00          3.00  ...        831.00
# std           76.34         79.13          0.59  ...        136.99
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count                 36.00         36.00          36.00         36.00
# mean                   0.97         17.97          15.17          3.08
# min                    0.00          1.00           0.00          0.00
# 25%                    0.00         12.75          11.00          2.00
# 50%                    0.00         20.50          15.50          3.00
# 75%                    2.50         22.00          19.25          4.00
# max                    2.50         31.00          23.00          6.00
# std                    1.24          7.71           4.99          1.56
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count        36.00         36.00        36.00            36.00        36.0
# mean         17.94         15.28         3.06            29.08         0.0
# min           1.00          0.00         0.00             0.00         0.0
# 25%          12.75         11.00         2.00             0.00         0.0
# 50%          20.00         16.50         3.00             0.00         0.0
# 75%          22.00         20.00         4.00             6.50         0.0
# max          31.00         23.00         6.00           895.00         0.0
# std           7.70          5.12         1.57           148.66         0.0
#
# [8 rows x 26 columns]

# %%
# ONlY 6 RECORDS WITH INVALID RATECODEID AND ZERO FARE
ratecodeid_99[ratecodeid_99['total_amount'] == 0].shape
# Out:
# (6, 27)

# %%
nan_ratecodeid_99 = ratecodeid_99.isna().sum()
print(nan_ratecodeid_99)
# Out:
# vendorid                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# ratecodeid               0
# store_and_fwd_flag       0
# pulocationid             0
# dolocationid             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# drop_off_day             0
# drop_off_hour            0
# drop_off_dow             0
# pick_up_day              0
# pick_up_hour             0
# pick_up_dow              0
# duration_minute          0
# is_holiday               0
# math_check               0
# dtype: int64

# %% [markdown]
# ### CHECK DATES AND EXCLUDE RECORDS WITH DROP OF DATE OUTSIDE OF JANUARY
# Since the rate code is selected at drop off, I am assuming that the fare is also associated with the drop off. Records will be kept as long as the drop off time is in the month of Jan.

# %%
# CHECK IF RECORDS OUTSIDE OF JAN 2021 - BASED ON DROP OFF ONLY 
min_date = datetime(2021, 1, 1)
max_date = datetime(2021, 2, 1)
# Filter for dates less than the certain date
filtered_do_taxi_df = taxi_df[(taxi_df['tpep_dropoff_datetime'] < min_date) | (taxi_df['tpep_dropoff_datetime'] >= max_date)]
print(f"Records outside of Jan 2021: {filtered_do_taxi_df.shape[0]} ")
filtered_do_taxi_df.tail()
# Out:
# Records outside of Jan 2021: 137
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1271412         2  2021-01-31 23:58:47   2021-02-01 00:04:40              3.0
# 1369750         6  2021-01-31 23:01:21   2021-02-01 00:02:03              NaN
# 1369753         2  2021-01-31 23:56:00   2021-02-01 00:38:00              NaN
# 1369757         2  2021-01-31 23:19:00   2021-02-01 00:22:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 1271412           0.81         1.0                 2.0            41
# 1369750          12.65         NaN                 NaN           265
# 1369753          19.61         NaN                 NaN           136
# 1369757          23.28         NaN                 NaN           155
# 1369767          19.70         NaN                 NaN           265
#
#          dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 1271412            74             2  ...                   0.0             1
# 1369750           215             0  ...                   NaN             1
# 1369753            10             0  ...                   NaN             1
# 1369757           246             0  ...                   NaN             1
# 1369767           188             0  ...                   NaN             1
#
#          drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 1271412              0             0           31            23            6
# 1369750              0             0           31            23            6
# 1369753              0             0           31            23            6
# 1369757              0             0           31            23            6
# 1369767              0             0           31            23            6
#
#          duration_minute  is_holiday  math_check
# 1271412                6       False         0.0
# 1369750               61       False         NaN
# 1369753               42       False         NaN
# 1369757               63       False         NaN
# 1369767               61       False         NaN
#
# [5 rows x 27 columns]

# %%
nan_filtered_do_taxi_df = filtered_do_taxi_df[filtered_do_taxi_df.isna().any(axis=1)]
nan_filtered_do_taxi_df.head()
# Out:
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1369750         6  2021-01-31 23:01:21   2021-02-01 00:02:03              NaN
# 1369753         2  2021-01-31 23:56:00   2021-02-01 00:38:00              NaN
# 1369757         2  2021-01-31 23:19:00   2021-02-01 00:22:00              NaN
# 1369767         6  2021-01-31 23:01:06   2021-02-01 00:02:03              NaN
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 1369750          12.65         NaN                 NaN           265
# 1369753          19.61         NaN                 NaN           136
# 1369757          23.28         NaN                 NaN           155
# 1369767          19.70         NaN                 NaN           265
#
#          dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 1369750           215             0  ...                   NaN             1
# 1369753            10             0  ...                   NaN             1
# 1369757           246             0  ...                   NaN             1
# 1369767           188             0  ...                   NaN             1
#
#          drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 1369750              0             0           31            23            6
# 1369753              0             0           31            23            6
# 1369757              0             0           31            23            6
# 1369767              0             0           31            23            6
#
#          duration_minute  is_holiday  math_check
# 1369750               61       False         NaN
# 1369753               42       False         NaN
# 1369757               63       False         NaN
# 1369767               61       False         NaN
#
# [4 rows x 27 columns]

# %%
nan_filtered_do_taxi_df = filtered_do_taxi_df.isna().sum()
print(nan_filtered_do_taxi_df)
# Out:
# vendorid                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          4
# trip_distance            0
# ratecodeid               4
# store_and_fwd_flag       4
# pulocationid             0
# dolocationid             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     4
# drop_off_day             0
# drop_off_hour            0
# drop_off_dow             0
# pick_up_day              0
# pick_up_hour             0
# pick_up_dow              0
# duration_minute          0
# is_holiday               0
# math_check               4
# dtype: int64

# %%
# CHECK IF THESE INCLUDE NEGATIVE VALUES
for col in filtered_do_taxi_df.columns:
    if filtered_do_taxi_df[col].dtype != 'datetime64[us]':
        negatives = (filtered_do_taxi_df[col] < 0).sum()
        if negatives > 0: 
            print(f"    {col}: {negatives}")
        else:
            print(f"    {col}: no negatives")
# Out:
#     vendorid: no negatives
#     passenger_count: no negatives
#     trip_distance: no negatives
#     ratecodeid: no negatives
#     store_and_fwd_flag: no negatives
#     pulocationid: no negatives
#     dolocationid: no negatives
#     payment_type: no negatives
#     fare_amount: no negatives
#     extra: no negatives
#     mta_tax: no negatives
#     tip_amount: no negatives
#     tolls_amount: no negatives
#     improvement_surcharge: no negatives
#     total_amount: no negatives
#     congestion_surcharge: no negatives
#     drop_off_day: no negatives
#     drop_off_hour: no negatives
#     drop_off_dow: no negatives
#     pick_up_day: no negatives
#     pick_up_hour: no negatives
#     pick_up_dow: no negatives
#     duration_minute: 1
#     is_holiday: no negatives
#     math_check: 19

# %%
# CHECK IF RECORDS OUTSIDE OF JAN 2021 - BASED ON PICK UP AND DROP OFF 
min_date = datetime(2021, 1, 1)
max_date = datetime(2021, 2, 1)
# Filter for dates less than the certain date
filtered_dopu_taxi_df_clean = taxi_df[((taxi_df['tpep_pickup_datetime'] < min_date) & (taxi_df['tpep_dropoff_datetime'] < min_date)) 
                      | ((taxi_df['tpep_pickup_datetime'] > max_date) & (taxi_df['tpep_dropoff_datetime'] > max_date))]
print(f"Records outside of Jan 2021: {filtered_dopu_taxi_df_clean.shape[0]} ")
filtered_dopu_taxi_df_clean.head(20)
# Out:
# Records outside of Jan 2021: 17
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 530             2  2020-12-31 21:40:20   2020-12-31 22:16:09              1.0
# 936             2  2020-12-31 13:44:02   2020-12-31 13:53:43              1.0
# 1661            2  2020-12-31 21:35:59   2020-12-31 21:38:20              1.0
# 1662            2  2020-12-31 21:43:40   2020-12-31 21:52:26              1.0
# 1880            2  2020-12-31 23:31:29   2020-12-31 23:37:51              1.0
# 2846            2  2020-12-31 18:25:31   2020-12-31 18:35:41              1.0
# 3448            2  2020-12-31 18:00:30   2020-12-31 18:07:50              1.0
# 3474            2  2020-12-31 23:06:12   2020-12-31 23:18:39              1.0
# 3783            2  2020-12-31 18:11:53   2020-12-31 18:17:04              1.0
# 392747          2  2021-02-01 08:16:53   2021-02-01 08:19:38              2.0
# 392748          2  2021-02-01 08:23:01   2021-02-01 08:29:36              1.0
# 392749          2  2021-02-01 08:43:05   2021-02-01 08:54:04              2.0
# 396240          2  2021-02-22 16:52:16   2021-02-22 16:56:15              1.0
# 518899          2  2009-01-01 00:10:40   2009-01-01 00:23:59              1.0
# 1015552         2  2008-12-31 23:05:14   2008-12-31 23:07:22              1.0
# 1152322         2  2009-01-01 00:26:37   2009-01-01 00:34:54              1.0
# 1178911         2  2009-01-01 00:03:15   2009-01-01 00:14:19              6.0
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 530              17.96         1.0                 2.0           249
# 936               3.76         1.0                 2.0           170
# 1661              0.66         1.0                 2.0            75
# 1662              2.15         1.0                 2.0           263
# 1880              1.57         1.0                 2.0           137
# 2846              2.72         1.0                 2.0           142
# 3448              2.20         1.0                 2.0           142
# 3474              7.08         1.0                 2.0            42
# 3783              1.74         1.0                 2.0            48
# 392747            0.73         1.0                 2.0           164
# 392748            1.39         1.0                 2.0           162
# 392749            1.68         1.0                 2.0           229
# 396240            0.72         1.0                 2.0           233
# 518899            1.46         1.0                 2.0           188
# 1015552           0.00         1.0                 2.0           193
# 1152322           4.09         1.0                 2.0           132
# 1178911           1.31         1.0                 2.0            41
#
#          dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 530               213             2  ...                   2.5            31
# 936               226             1  ...                   2.5            31
# 1661               74             2  ...                   0.0            31
# 1662               74             2  ...                   2.5            31
# 1880               79             1  ...                   2.5            31
# 2846              233             1  ...                   2.5            31
# 3448               68             1  ...                   2.5            31
# 3474              137             2  ...                   2.5            31
# 3783              239             1  ...                   2.5            31
# 392747            161             1  ...                   2.5             1
# 392748            141             1  ...                   2.5             1
# 392749             48             2  ...                   2.5             1
# 396240            170             1  ...                   2.5            22
# 518899             89             2  ...                   0.0             1
# 1015552           193             2  ...                   0.0            31
# 1152322            10             2  ...                   0.0             1
# 1178911           238             2  ...                   2.5             1
#
#          drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 530                 22             3           31            21            3
# 936                 13             3           31            13            3
# 1661                21             3           31            21            3
# 1662                21             3           31            21            3
# 1880                23             3           31            23            3
# 2846                18             3           31            18            3
# 3448                18             3           31            18            3
# 3474                23             3           31            23            3
# 3783                18             3           31            18            3
# 392747               8             0            1             8            0
# 392748               8             0            1             8            0
# 392749               8             0            1             8            0
# 396240              16             0           22            16            0
# 518899               0             3            1             0            3
# 1015552             23             2           31            23            2
# 1152322              0             3            1             0            3
# 1178911              0             3            1             0            3
#
#          duration_minute  is_holiday  math_check
# 530                   36       False         0.0
# 936                   10       False        -0.0
# 1661                   2       False         0.0
# 1662                   9       False         0.0
# 1880                   6       False        -0.0
# 2846                  10       False         0.0
# 3448                   7       False         0.0
# 3474                  12       False         0.0
# 3783                   5       False        -0.0
# 392747                 3       False         0.0
# 392748                 7       False         0.0
# 392749                11       False         0.0
# 396240                 4       False         0.0
# 518899                13       False         0.0
# 1015552                2       False         0.0
# 1152322                8       False         0.0
# 1178911               11       False         0.0
#
# [17 rows x 27 columns]

# %% [markdown]
# # DROP ROWS BASED ON ABOVE
# 1. With negative fare amount - 6769 records 114 of which fall into another bucket (NaN)
# 2. With invalid ratecodeid - 36
# 3. With NaNs - 98352 records
# 4. With drop off time not in Jan 2021 - 137 records 4 of which fall into another bucket (NaN)

# %%
# EXPECTED ROWS TO DROP
print(f'Expected dropped rows: {6769 - 114 + 36 + 98352 + 137 - 4}')
# Out:
# Expected dropped rows: 105176

# %%
taxi_df_clean = (
    taxi_df[taxi_df['fare_amount'] >= 0]
    .query('ratecodeid != 99')
    .query('@min_date <= tpep_dropoff_datetime < @max_date')
    .dropna()
)
print(f'Dropped Rows: {1369769 - taxi_df_clean.shape[0]}')
# Out:
# Dropped Rows: 105176

# %% [markdown]
# # OUTLIERS

# %%
taxi_df_clean.describe().round(2)
# Out:
#          vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  1264593.00                     1264593                     1264593
# mean         1.68  2021-01-17 02:46:38.668871  2021-01-17 03:00:02.465708
# min          1.00         2020-12-31 18:35:16         2021-01-01 00:01:40
# 25%          1.00         2021-01-09 14:13:19         2021-01-09 14:24:55
# 50%          2.00         2021-01-16 21:37:43         2021-01-16 21:51:17
# 75%          2.00         2021-01-24 15:42:16         2021-01-24 15:54:15
# max          2.00         2021-01-31 23:52:20         2021-01-31 23:59:44
# std          0.47                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count       1264593.00     1264593.00  1264593.00          1264593.00
# mean              1.41           2.70        1.03                1.98
# min               0.00           0.00        1.00                1.00
# 25%               1.00           0.99        1.00                2.00
# 50%               1.00           1.61        1.00                2.00
# 75%               1.00           2.79        1.00                2.00
# max               8.00      114328.20        6.00                2.00
# std               1.06         101.72        0.29                0.12
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count    1264593.00    1264593.00    1264593.00  ...    1264593.00
# mean         166.34        163.51          1.27  ...         16.58
# min            1.00          1.00          1.00  ...          0.00
# 25%          132.00        107.00          1.00  ...         10.70
# 50%          162.00        162.00          1.00  ...         13.50
# 75%          236.00        236.00          2.00  ...         17.80
# max          265.00        265.00          4.00  ...       7661.28
# std           66.51         71.39          0.47  ...         13.90
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count            1264593.00    1264593.00     1264593.00    1264593.00
# mean                   2.26         16.52          13.96          2.98
# min                    0.00          1.00           0.00          0.00
# 25%                    2.50          9.00          11.00          1.00
# 50%                    2.50         16.00          14.00          3.00
# 75%                    2.50         24.00          17.00          5.00
# max                    3.00         31.00          23.00          6.00
# std                    0.73          8.64           4.58          1.90
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count   1264593.00    1264593.00   1264593.00       1264593.00  1264593.00
# mean         16.52         13.84         2.98            13.40       -0.72
# min           1.00          0.00         0.00            -4.00       -2.50
# 25%           9.00         11.00         1.00             5.00       -2.50
# 50%          16.00         14.00         3.00             9.00        0.00
# 75%          24.00         17.00         5.00            14.00        0.00
# max          31.00         23.00         6.00         28818.00        5.00
# std           8.64          4.54         1.90            64.13        1.14
#
# [8 rows x 26 columns]

# %%
# VERY LONG TRIP DISTANCE 
print(taxi_df_clean.shape[0])
taxi_df_clean.drop(taxi_df_clean[taxi_df_clean['trip_distance'] >= 500].index, inplace = True)
print(taxi_df_clean.shape[0])
# Out:
# 1264593
# 1264592

# %%
# UNBELIEVABLE FARE AMOUNTS 
# The records with trip distance 0 or 2 miles and high fare amounts are likely to be errors or money laundering. 
print(taxi_df_clean[(taxi_df_clean['fare_amount'] >= 300) & (taxi_df_clean['trip_distance'] <= 10)].shape[0])
taxi_df_clean[(taxi_df_clean['fare_amount'] >= 300) & (taxi_df_clean['trip_distance'] <= 10)].head()
# Out:
# 27
#         vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 80551          2  2021-01-04 04:32:36   2021-01-04 04:32:42              1.0
# 108758         2  2021-01-04 16:04:51   2021-01-04 16:15:01              1.0
# 198990         2  2021-01-06 17:08:43   2021-01-06 17:08:49              2.0
# 256410         2  2021-01-08 02:20:52   2021-01-08 02:21:03              1.0
# 296351         1  2021-01-08 19:53:41   2021-01-08 19:54:40              1.0
#
#         trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 80551            0.00         5.0                 2.0           100
# 108758           2.05         1.0                 2.0           140
# 198990           0.00         5.0                 2.0            13
# 256410           0.00         5.0                 2.0           132
# 296351           0.00         5.0                 2.0           164
#
#         dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 80551            100             2  ...                   2.5             4
# 108758           236             1  ...                   2.5             4
# 198990            13             2  ...                   2.5             6
# 256410           132             1  ...                   0.0             8
# 296351           100             1  ...                   0.0             8
#
#         drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 80551               4             0            4             4            0
# 108758             16             0            4            16            0
# 198990             17             2            6            17            2
# 256410              2             4            8             2            4
# 296351             19             4            8            19            4
#
#         duration_minute  is_holiday  math_check
# 80551                 0       False         0.0
# 108758               10       False        -0.0
# 198990                0       False         0.0
# 256410                0       False         0.0
# 296351                1       False         0.0
#
# [5 rows x 27 columns]

# %%
# VERY HIGH FARE AMOUNTS AS IT SKEWS THE DATA - THESE OUTLIERS CAN BE LOOKED AT INDIVIDUALLY
print(taxi_df_clean[taxi_df_clean['total_amount'] >= 500].shape[0])
# Out:
# 15

# %%
# LOOK AT RECORDS WITH FARE AMOUNT GREATER THAN $300, 0 DISTANCE, AND DURATION LESS THAN 2 MINUTES 
# These are likely errors or money laundering  -  1297 records
zero_distance2 = (
    taxi_df_clean[(taxi_df_clean['trip_distance'] == 0) 
    & (taxi_df_clean['duration_minute'] < 2)
    & (taxi_df_clean['total_amount'] > 50)]
)
print(zero_distance2.shape[0])  
zero_distance2.sort_values(by=['total_amount'], ascending=False).head(20)
# Out:
# 1482
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 267047          1  2021-01-08 11:02:54   2021-01-08 11:02:58              1.0
# 1003476         2  2021-01-25 18:04:46   2021-01-25 18:04:54              3.0
# 368233          1  2021-01-11 01:52:50   2021-01-11 01:53:58              0.0
# 1003478         2  2021-01-25 18:06:12   2021-01-25 18:06:20              3.0
# 1007442         2  2021-01-25 21:11:38   2021-01-25 21:11:49              2.0
# 256410          2  2021-01-08 02:20:52   2021-01-08 02:21:03              1.0
# 1256718         2  2021-01-31 14:51:30   2021-01-31 14:52:34              1.0
# 1271075         2  2021-01-31 22:16:10   2021-01-31 22:16:20              2.0
# 1267438         2  2021-01-31 18:19:04   2021-01-31 18:19:12              3.0
# 504336          2  2021-01-14 00:14:48   2021-01-14 00:15:50              1.0
# 1193225         2  2021-01-29 17:13:22   2021-01-29 17:13:35              4.0
# 627507          2  2021-01-16 17:01:28   2021-01-16 17:01:52              1.0
# 1263103         2  2021-01-31 16:27:30   2021-01-31 16:27:39              1.0
# 1241291         2  2021-01-30 22:54:53   2021-01-30 22:54:56              1.0
# 198990          2  2021-01-06 17:08:43   2021-01-06 17:08:49              2.0
# 296351          1  2021-01-08 19:53:41   2021-01-08 19:54:40              1.0
# 681737          2  2021-01-18 13:58:10   2021-01-18 13:58:15              1.0
# 832077          1  2021-01-21 17:51:49   2021-01-21 17:52:57              1.0
# 423218          2  2021-01-12 10:20:46   2021-01-12 10:20:50              1.0
# 937624          2  2021-01-24 02:24:00   2021-01-24 02:24:18              1.0
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 267047             0.0         1.0                 2.0           145
# 1003476            0.0         5.0                 2.0           236
# 368233             0.0         5.0                 2.0           265
# 1003478            0.0         5.0                 2.0           236
# 1007442            0.0         5.0                 2.0            90
# 256410             0.0         5.0                 2.0           132
# 1256718            0.0         5.0                 2.0           265
# 1271075            0.0         5.0                 2.0            26
# 1267438            0.0         5.0                 2.0           163
# 504336             0.0         5.0                 2.0            68
# 1193225            0.0         5.0                 2.0           132
# 627507             0.0         5.0                 2.0           265
# 1263103            0.0         5.0                 2.0           256
# 1241291            0.0         5.0                 2.0           264
# 198990             0.0         5.0                 2.0            13
# 296351             0.0         5.0                 2.0           164
# 681737             0.0         5.0                 2.0           265
# 832077             0.0         5.0                 2.0           132
# 423218             0.0         5.0                 2.0           265
# 937624             0.0         5.0                 2.0            75
#
#          dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 267047            145             2  ...                   0.0             8
# 1003476           236             1  ...                   2.5            25
# 368233            265             1  ...                   0.0            11
# 1003478           236             2  ...                   2.5            25
# 1007442            90             1  ...                   2.5            25
# 256410            132             1  ...                   0.0             8
# 1256718           265             1  ...                   0.0            31
# 1271075            26             1  ...                   0.0            31
# 1267438           163             1  ...                   2.5            31
# 504336             68             1  ...                   2.5            14
# 1193225           132             2  ...                   0.0            29
# 627507            265             1  ...                   0.0            16
# 1263103           256             1  ...                   0.0            31
# 1241291           264             1  ...                   0.0            30
# 198990             13             2  ...                   2.5             6
# 296351            100             1  ...                   0.0             8
# 681737            265             1  ...                   0.0            18
# 832077            132             1  ...                   0.0            21
# 423218            265             2  ...                   0.0            12
# 937624             75             1  ...                   0.0            24
#
#          drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 267047              11             4            8            11            4
# 1003476             18             0           25            18            0
# 368233               1             0           11             1            0
# 1003478             18             0           25            18            0
# 1007442             21             0           25            21            0
# 256410               2             4            8             2            4
# 1256718             14             6           31            14            6
# 1271075             22             6           31            22            6
# 1267438             18             6           31            18            6
# 504336               0             3           14             0            3
# 1193225             17             4           29            17            4
# 627507              17             5           16            17            5
# 1263103             16             6           31            16            6
# 1241291             22             5           30            22            5
# 198990              17             2            6            17            2
# 296351              19             4            8            19            4
# 681737              13             0           18            13            0
# 832077              17             3           21            17            3
# 423218              10             1           12            10            1
# 937624               2             6           24             2            6
#
#          duration_minute  is_holiday  math_check
# 267047                 0       False        -0.0
# 1003476                0       False         0.0
# 368233                 1       False         0.0
# 1003478                0       False         0.0
# 1007442                0       False         0.0
# 256410                 0       False         0.0
# 1256718                1       False        -0.0
# 1271075                0       False         0.0
# 1267438                0       False         0.0
# 504336                 1       False         0.0
# 1193225                0       False         0.0
# 627507                 0       False         0.0
# 1263103                0       False        -0.0
# 1241291                0       False        -0.0
# 198990                 0       False         0.0
# 296351                 1       False         0.0
# 681737                 0        True        -0.0
# 832077                 1       False         0.0
# 423218                 0       False         0.0
# 937624                 0       False         0.0
#
# [20 rows x 27 columns]

# %%
# DROP THE RECORDS WITH FARE AMOUNT GREATER THAN $300, 0 DISTANCE, AND DURATION LESS THAN 2 MINUTES
taxi_df_clean = taxi_df_clean[~((taxi_df_clean['trip_distance'] == 0) & (taxi_df_clean['duration_minute'] < 2) & (taxi_df_clean['total_amount'] > 50))]
taxi_df_clean.shape[0]
# Out:
# 1263110

# %%
# DROP THE RECORDS WITH TOTAL FARE AMOUNT GREATER THAN $500
taxi_df_clean = taxi_df_clean[~(taxi_df_clean['total_amount'] > 500)]
taxi_df_clean.shape[0]
# Out:
# 1263098

# %%
# LONG DURATION TRIPS  - THE DRIVER LIKELY FORGOT TO TURN OFF THE METER
# LEAVE THEM IN THE DATASET BUT EXCLUDE FROM DURATION ANALYSIS
print(taxi_df_clean[(taxi_df_clean['duration_minute'] >= 500) & (taxi_df_clean['trip_distance'] < 200)].shape[0])
print(taxi_df_clean[(taxi_df_clean['duration_minute'] >= 1000)].shape[0])
taxi_df_clean[taxi_df_clean['duration_minute'] >= 1000].sort_values(by=['trip_distance'], ascending=False).head(20)
# Out:
# 2315
# 2146
#          vendorid tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 845003          2  2021-01-21 22:49:50   2021-01-22 20:29:30              6.0
# 990439          2  2021-01-25 14:35:50   2021-01-26 11:35:41              1.0
# 21339           2  2021-01-01 21:02:02   2021-01-02 20:41:45              2.0
# 793958          2  2021-01-20 21:07:16   2021-01-21 20:44:46              2.0
# 154007          2  2021-01-05 17:33:34   2021-01-06 15:24:06              1.0
# 10601           2  2021-01-01 12:23:19   2021-01-02 12:09:31              1.0
# 1091383         2  2021-01-27 18:24:39   2021-01-28 18:03:09              1.0
# 484859          2  2021-01-13 15:24:59   2021-01-14 15:24:52              1.0
# 698769          2  2021-01-18 19:50:17   2021-01-19 19:25:45              4.0
# 26824           2  2021-01-02 10:38:28   2021-01-03 10:15:14              4.0
# 955310          2  2021-01-24 16:36:04   2021-01-25 16:10:33              4.0
# 48600           2  2021-01-02 19:27:18   2021-01-03 18:13:49              1.0
# 588042          2  2021-01-15 17:18:00   2021-01-16 16:56:55              1.0
# 365177          2  2021-01-10 20:41:48   2021-01-11 20:15:24              1.0
# 78319           2  2021-01-03 21:56:40   2021-01-04 20:37:45              1.0
# 352380          2  2021-01-10 14:11:06   2021-01-11 13:49:40              6.0
# 314278          2  2021-01-08 18:12:15   2021-01-09 13:31:41              1.0
# 685136          2  2021-01-18 14:04:46   2021-01-19 13:45:24              4.0
# 77304           2  2021-01-03 20:06:34   2021-01-04 19:03:32              1.0
# 133214          2  2021-01-05 10:24:56   2021-01-06 09:52:34              5.0
#
#          trip_distance  ratecodeid  store_and_fwd_flag  pulocationid  \
# 845003           42.37         4.0                 2.0           132
# 990439           34.78         5.0                 2.0           132
# 21339            29.70         4.0                 2.0           132
# 793958           24.75         4.0                 2.0           132
# 154007           23.07         1.0                 2.0           132
# 10601            22.60         3.0                 2.0           132
# 1091383          22.29         2.0                 2.0           132
# 484859           22.15         5.0                 2.0           132
# 698769           21.98         2.0                 2.0           132
# 26824            21.26         2.0                 2.0           132
# 955310           21.20         2.0                 2.0           132
# 48600            21.20         2.0                 2.0           132
# 588042           21.14         2.0                 2.0           107
# 365177           21.02         1.0                 2.0           132
# 78319            20.72         2.0                 2.0           132
# 352380           20.62         2.0                 2.0           132
# 314278           20.56         2.0                 2.0            86
# 685136           20.39         2.0                 2.0           132
# 77304            20.15         2.0                 2.0           132
# 133214           19.99         1.0                 2.0           132
#
#          dolocationid  payment_type  ...  congestion_surcharge  drop_off_day  \
# 845003            265             1  ...                   0.0            22
# 990439            265             2  ...                   2.5            26
# 21339             265             1  ...                   0.0             2
# 793958            265             2  ...                   0.0            21
# 154007            153             1  ...                   0.0             6
# 10601             265             2  ...                   0.0             2
# 1091383           127             2  ...                   0.0            28
# 484859            265             1  ...                   0.0            14
# 698769            261             1  ...                   2.5            19
# 26824             239             1  ...                   0.0             3
# 955310            243             2  ...                   0.0            25
# 48600             239             1  ...                   2.5             3
# 588042            132             1  ...                   2.5            16
# 365177            174             1  ...                   0.0            11
# 78319             231             1  ...                   2.5             4
# 352380             43             1  ...                   0.0            11
# 314278            140             1  ...                   0.0             9
# 685136             75             1  ...                   0.0            19
# 77304             236             1  ...                   2.5             4
# 133214             14             2  ...                   0.0             6
#
#          drop_off_hour  drop_off_dow  pick_up_day  pick_up_hour  pick_up_dow  \
# 845003              20             4           21            22            3
# 990439              11             1           25            14            0
# 21339               20             5            1            21            4
# 793958              20             3           20            21            2
# 154007              15             2            5            17            1
# 10601               12             5            1            12            4
# 1091383             18             3           27            18            2
# 484859              15             3           13            15            2
# 698769              19             1           18            19            0
# 26824               10             6            2            10            5
# 955310              16             0           24            16            6
# 48600               18             6            2            19            5
# 588042              16             5           15            17            4
# 365177              20             0           10            20            6
# 78319               20             0            3            21            6
# 352380              13             0           10            14            6
# 314278              13             5            8            18            4
# 685136              13             1           18            14            0
# 77304               19             0            3            20            6
# 133214               9             2            5            10            1
#
#          duration_minute  is_holiday  math_check
# 845003              1300       False        -0.0
# 990439              1260       False         0.0
# 21339               1420       False         0.0
# 793958              1418       False         0.0
# 154007              1311       False         0.0
# 10601               1426       False         0.0
# 1091383             1418       False         0.0
# 484859              1440       False        -0.0
# 698769              1415       False         0.0
# 26824               1417       False         0.0
# 955310              1414       False         0.0
# 48600               1367       False         0.0
# 588042              1419       False         0.0
# 365177              1414       False         0.0
# 78319               1361       False         0.0
# 352380              1419       False         0.0
# 314278              1159       False         0.0
# 685136              1421       False         0.0
# 77304               1377       False         0.0
# 133214              1408       False         0.0
#
# [20 rows x 27 columns]

# %% [markdown]
# # NO CHARGE (payment_type = 3) and DISPUTE TRIPS (payment_type = 4)
# Review some records

# %%
no_charge = taxi_df_clean[taxi_df_clean['payment_type'] == 3]   
print(f'No charge records: {no_charge.shape[0]}')
no_charge.describe().round(2)
# Out:
# No charge records: 6159
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count    6159.0                        6159                        6159
# mean        1.0  2021-01-16 18:45:03.949180  2021-01-16 18:55:01.079720
# min         1.0         2021-01-01 00:03:13         2021-01-01 00:03:19
# 25%         1.0         2021-01-08 17:42:11  2021-01-08 17:44:15.500000
# 50%         1.0         2021-01-16 07:22:55         2021-01-16 07:23:19
# 75%         1.0         2021-01-24 19:06:14         2021-01-24 19:19:33
# max         1.0         2021-01-31 23:21:15         2021-01-31 23:24:30
# std         0.0                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count          6159.00        6159.00     6159.00             6159.00
# mean              1.06           2.81        1.13                1.94
# min               0.00           0.00        1.00                1.00
# 25%               1.00           0.40        1.00                2.00
# 50%               1.00           1.30        1.00                2.00
# 75%               1.00           3.10        1.00                2.00
# max               6.00          86.80        6.00                2.00
# std               0.58           4.39        0.67                0.23
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count       6159.00       6159.00        6159.0  ...       6159.00
# mean         157.69        154.21           3.0  ...         14.35
# min            3.00          1.00           3.0  ...          0.00
# 25%          114.00         90.00           3.0  ...          6.80
# 50%          148.00        151.00           3.0  ...         10.30
# 75%          230.00        231.00           3.0  ...         16.80
# max          265.00        265.00           3.0  ...        196.30
# std           64.58         72.58           0.0  ...         13.26
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count               6159.00       6159.00        6159.00       6159.00
# mean                   1.85         16.19          13.82          3.05
# min                    0.00          1.00           0.00          0.00
# 25%                    0.00          8.00          11.00          1.00
# 50%                    2.50         16.00          14.00          3.00
# 75%                    2.50         24.00          18.00          5.00
# max                    2.50         31.00          23.00          6.00
# std                    1.10          8.96           5.37          1.90
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count      6159.00       6159.00      6159.00          6159.00     6159.00
# mean         16.19         13.74         3.05             9.94       -1.85
# min           1.00          0.00         0.00             0.00       -2.50
# 25%           8.00         10.00         1.00             2.00       -2.50
# 50%          16.00         14.00         3.00             7.00       -2.50
# 75%          24.00         18.00         5.00            14.00        0.00
# max          31.00         23.00         6.00           238.00        0.00
# std           8.96          5.33         1.90            11.23        1.10
#
# [8 rows x 26 columns]

# %%
dispute = taxi_df_clean[taxi_df_clean['payment_type'] == 4]   
print(f'Dispute records: {dispute.shape[0]}')
dispute.describe().round(2)
# Out:
# Dispute records: 2196
#        vendorid        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count    2196.0                        2196                        2196
# mean        1.0  2021-01-16 08:50:40.872040  2021-01-16 09:00:59.481329
# min         1.0         2021-01-01 00:06:20         2021-01-01 00:14:20
# 25%         1.0  2021-01-08 15:49:47.750000  2021-01-08 15:59:21.250000
# 50%         1.0         2021-01-15 16:17:46         2021-01-15 16:24:49
# 75%         1.0  2021-01-23 18:25:55.250000         2021-01-23 18:31:37
# max         1.0         2021-01-31 23:08:47         2021-01-31 23:26:28
# std         0.0                         NaN                         NaN
#
#        passenger_count  trip_distance  ratecodeid  store_and_fwd_flag  \
# count          2196.00        2196.00     2196.00             2196.00
# mean              1.06           2.81        1.12                1.94
# min               0.00           0.00        1.00                1.00
# 25%               1.00           0.60        1.00                2.00
# 50%               1.00           1.40        1.00                2.00
# 75%               1.00           3.00        1.00                2.00
# max               6.00          95.50        5.00                2.00
# std               0.55           4.68        0.65                0.23
#
#        pulocationid  dolocationid  payment_type  ...  total_amount  \
# count       2196.00       2196.00        2196.0  ...       2196.00
# mean         157.36        151.96           4.0  ...         14.48
# min            1.00          1.00           4.0  ...          0.00
# 25%          107.00         79.00           4.0  ...          7.80
# 50%          158.00        151.00           4.0  ...         10.80
# 75%          233.00        233.00           4.0  ...         16.30
# max          265.00        265.00           4.0  ...        158.08
# std           68.31         75.33           0.0  ...         12.86
#
#        congestion_surcharge  drop_off_day  drop_off_hour  drop_off_dow  \
# count               2196.00       2196.00        2196.00       2196.00
# mean                   1.97         15.78          13.83          2.97
# min                    0.00          1.00           0.00          0.00
# 25%                    2.50          8.00          11.00          1.00
# 50%                    2.50         15.00          14.00          3.00
# 75%                    2.50         23.00          18.00          5.00
# max                    2.50         31.00          23.00          6.00
# std                    1.02          8.80           5.24          1.94
#
#        pick_up_day  pick_up_hour  pick_up_dow  duration_minute  math_check
# count      2196.00       2196.00      2196.00          2196.00     2196.00
# mean         15.78         13.75         2.97            10.28       -1.97
# min           1.00          0.00         0.00             0.00       -2.50
# 25%           8.00         11.00         1.00             3.00       -2.50
# 50%          15.00         14.00         3.00             7.00       -2.50
# 75%          23.00         18.00         5.00            14.00       -2.50
# max          31.00         23.00         6.00           123.00        0.00
# std           8.80          5.19         1.94            10.58        1.02
#
# [8 rows x 26 columns]

# %% [markdown]
# # EXPORT CLEANED DATA TO FILE

# %%
taxi_df_clean.to_parquet('data/yellow_taxi_jan_2021_clean.parquet')
taxi_df_clean.to_pickle("data/yellow_taxi_jan_2021_clean.pkl")

# %%
taxi_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1263098 entries, 0 to 1271416
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   vendorid               1263098 non-null  int64
#  1   tpep_pickup_datetime   1263098 non-null  datetime64[us]
#  2   tpep_dropoff_datetime  1263098 non-null  datetime64[us]
#  3   passenger_count        1263098 non-null  float64
#  4   trip_distance          1263098 non-null  float64
#  5   ratecodeid             1263098 non-null  float64
#  6   store_and_fwd_flag     1263098 non-null  float64
#  7   pulocationid           1263098 non-null  int64
#  8   dolocationid           1263098 non-null  int64
#  9   payment_type           1263098 non-null  int64
#  10  fare_amount            1263098 non-null  float64
#  11  extra                  1263098 non-null  float64
#  12  mta_tax                1263098 non-null  float64
#  13  tip_amount             1263098 non-null  float64
#  14  tolls_amount           1263098 non-null  float64
#  15  improvement_surcharge  1263098 non-null  float64
#  16  total_amount           1263098 non-null  float64
#  17  congestion_surcharge   1263098 non-null  float64
#  18  drop_off_day           1263098 non-null  int32
#  19  drop_off_hour          1263098 non-null  int32
#  20  drop_off_dow           1263098 non-null  int32
#  21  pick_up_day            1263098 non-null  int32
#  22  pick_up_hour           1263098 non-null  int32
#  23  pick_up_dow            1263098 non-null  int32
#  24  duration_minute        1263098 non-null  int64
#  25  is_holiday             1263098 non-null  bool
#  26  math_check             1263098 non-null  float64
# dtypes: bool(1), datetime64[us](2), float64(13), int32(6), int64(5)
# memory usage: 232.5 MB

# %%
categorical_cols = ['passenger_count', 'vendorid', 'ratecodeid', 'store_and_fwd_flag','payment_type', 'pulocationid', 'dolocationid','drop_off_day', 'drop_off_hour','drop_off_dow', 'pick_up_day', 'pick_up_hour', 'pick_up_dow','is_holiday']
print(len(categorical_cols))

numeric_cols = ['trip_distance', 'duration_minute', 'total_amount', 'fare_amount', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'mta_tax', 'extra', 'congestion_surcharge', 'math_check']
print(len(numeric_cols))
# Out:
# 14
# 11

# %%
fig, axs = plt.subplots(4, 3, figsize=(12, 8))

for i, column in enumerate(numeric_cols):
    taxi_var = taxi_df_clean[column]
    mean = taxi_var.mean()
    std_dev = taxi_var.std()
    
    row = i // 3
    col = i % 3
    
    sns.histplot(taxi_var, bins=3000, ax=axs[row, col])
    axs[row, col].set_title(column.capitalize())
    
    # Set x-axis limits based on min and max values in the column
    axs[row, col].set_xlim(mean - 3*std_dev, mean + 3*std_dev)
    
    axs[row, col].axvline(taxi_var.mean(), color='red', label='Mean')
    axs[row, col].axvline(taxi_var.mean() - taxi_var.std(), color='green', linestyle='--', label='Std Dev')
    axs[row, col].axvline(taxi_var.mean() + taxi_var.std(), color='green', linestyle='--')

# Add a single legend for all four plots
handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, bbox_to_anchor=(1, 1), loc='right', ncol=1)

# Add a title for the whole figure
fig.suptitle('Taxi Metrics Histograms', fontsize=16, y=1.05)

# Add some padding between the subplots
plt.subplots_adjust(hspace=1)

# display the plot
plt.show()

# %%
sns.boxplot(x='drop_off_day', y='fare_amount', data=taxi_df_clean, hue='drop_off_dow', palette='rainbow', showfliers=False, legend=False)
plt.xlabel('Drop-off Day of Month')
plt.ylabel('Total Amount')
plt.title('Boxplot of Total Amount by Drop-off Day of Week')
plt.show()

# %%
sns.violinplot(x='drop_off_dow', y='fare_amount', data=taxi_df, hue='drop_off_dow', palette='rainbow', legend=False)
plt.xlabel('Drop-off Day of Week')
plt.ylabel('Total Amount')
plt.title('Boxplot of Total Amount by Drop-off Day of Week')
plt.show()
